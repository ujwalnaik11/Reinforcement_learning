# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

# %% [markdown]
# # 2. Test Environment

# %%
# http://www.atarimania.com/roms/Roms.rar
# !python -m atari_py.import_roms .\ROMS\ROMS
# Out:
# copying adventure.bin from .\ROMS\ROMS\Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\adventure.bin
# copying air_raid.bin from .\ROMS\ROMS\Air Raid (Men-A-Vision) (PAL) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\air_raid.bin
# copying alien.bin from .\ROMS\ROMS\Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\alien.bin
# copying amidar.bin from .\ROMS\ROMS\Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\amidar.bin
# copying assault.bin from .\ROMS\ROMS\Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\assault.bin
# copying asterix.bin from .\ROMS\ROMS\Asterix (AKA Taz) (07-27-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\asterix.bin
# copying asteroids.bin from .\ROMS\ROMS\Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\asteroids.bin
# copying atlantis.bin from .\ROMS\ROMS\Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\atlantis.bin
# copying bank_heist.bin from .\ROMS\ROMS\Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\bank_heist.bin
# copying battle_zone.bin from .\ROMS\ROMS\Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\battle_zone.bin
# copying beam_rider.bin from .\ROMS\ROMS\Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\beam_rider.bin
# copying berzerk.bin from .\ROMS\ROMS\Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\berzerk.bin
# copying bowling.bin from .\ROMS\ROMS\Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\bowling.bin
# copying boxing.bin from .\ROMS\ROMS\Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\boxing.bin
# copying breakout.bin from .\ROMS\ROMS\Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\breakout.bin
# copying carnival.bin from .\ROMS\ROMS\Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\carnival.bin
# copying centipede.bin from .\ROMS\ROMS\Centipede (1983) (Atari - GCC) (CX2676) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\centipede.bin
# copying chopper_command.bin from .\ROMS\ROMS\Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\chopper_command.bin
# copying crazy_climber.bin from .\ROMS\ROMS\Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\crazy_climber.bin
# copying defender.bin from .\ROMS\ROMS\Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\defender.bin
# copying demon_attack.bin from .\ROMS\ROMS\Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\demon_attack.bin
# copying donkey_kong.bin from .\ROMS\ROMS\Donkey Kong (1982) (Coleco - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (2451) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\donkey_kong.bin
# copying double_dunk.bin from .\ROMS\ROMS\Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\double_dunk.bin
# copying elevator_action.bin from .\ROMS\ROMS\Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\elevator_action.bin
# copying enduro.bin from .\ROMS\ROMS\Enduro (1983) (Activision, Larry Miller) (AX-026, AX-026-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\enduro.bin
# copying fishing_derby.bin from .\ROMS\ROMS\Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\fishing_derby.bin
# copying freeway.bin from .\ROMS\ROMS\Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\freeway.bin
# copying frogger.bin from .\ROMS\ROMS\Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\frogger.bin
# copying frostbite.bin from .\ROMS\ROMS\Frostbite (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\frostbite.bin
# copying galaxian.bin from .\ROMS\ROMS\Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\galaxian.bin
# copying gopher.bin from .\ROMS\ROMS\Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\gopher.bin
# copying gravitar.bin from .\ROMS\ROMS\Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\gravitar.bin
# copying hero.bin from .\ROMS\ROMS\H.E.R.O. (1984) (Activision, John Van Ryzin) (AZ-036-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\hero.bin
# copying ice_hockey.bin from .\ROMS\ROMS\Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\ice_hockey.bin
# copying jamesbond.bin from .\ROMS\ROMS\James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Louis Marbel) (PB5110) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\jamesbond.bin
# copying journey_escape.bin from .\ROMS\ROMS\Journey Escape (1983) (Data Age, J. Ray Dettling) (112-006) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\journey_escape.bin
# copying kaboom.bin from .\ROMS\ROMS\Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, AG-010-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\kaboom.bin
# copying kangaroo.bin from .\ROMS\ROMS\Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\kangaroo.bin
# copying keystone_kapers.bin from .\ROMS\ROMS\Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\keystone_kapers.bin
# copying king_kong.bin from .\ROMS\ROMS\King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\king_kong.bin
# copying koolaid.bin from .\ROMS\ROMS\Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\koolaid.bin
# copying krull.bin from .\ROMS\ROMS\Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\krull.bin
# copying kung_fu_master.bin from .\ROMS\ROMS\Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\kung_fu_master.bin
# copying laser_gates.bin from .\ROMS\ROMS\Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\laser_gates.bin
# copying lost_luggage.bin from .\ROMS\ROMS\Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\lost_luggage.bin
# copying montezuma_revenge.bin from .\ROMS\ROMS\Montezuma's Revenge - Featuring Panama Joe (1984) (Parker Brothers - JWDA, Henry Will IV) (PB5760) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\montezuma_revenge.bin
# copying mr_do.bin from .\ROMS\ROMS\Mr. Do! (1983) (CBS Electronics, Ed English) (4L4478) (PAL).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\mr_do.bin
# copying ms_pacman.bin from .\ROMS\ROMS\Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\ms_pacman.bin
# copying name_this_game.bin from .\ROMS\ROMS\Name This Game (Guardians of Treasure) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\name_this_game.bin
# copying pacman.bin from .\ROMS\ROMS\Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\pacman.bin
# copying phoenix.bin from .\ROMS\ROMS\Phoenix (1983) (Atari - GCC, Mike Feinstein, John Mracek) (CX2673) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\phoenix.bin
# copying video_pinball.bin from .\ROMS\ROMS\Pinball (AKA Video Pinball) (Zellers).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\video_pinball.bin
# copying pitfall.bin from .\ROMS\ROMS\Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\pitfall.bin
# copying pooyan.bin from .\ROMS\ROMS\Pooyan (1983) (Konami) (RC 100-X 02) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\pooyan.bin
# copying private_eye.bin from .\ROMS\ROMS\Private Eye (1984) (Activision, Bob Whitehead) (AG-034-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\private_eye.bin
# copying qbert.bin from .\ROMS\ROMS\Q-bert (1983) (Parker Brothers - Western Technologies, Dave Hampton, Tom Sloper) (PB5360) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\qbert.bin
# copying riverraid.bin from .\ROMS\ROMS\River Raid (1982) (Activision, Carol Shaw) (AX-020, AX-020-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\riverraid.bin
# copying road_runner.bin from patched version of .\ROMS\ROMS\Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\road_runner.bin
# copying robotank.bin from .\ROMS\ROMS\Robot Tank (Robotank) (1983) (Activision, Alan Miller) (AZ-028, AG-028-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\robotank.bin
# copying seaquest.bin from .\ROMS\ROMS\Seaquest (1983) (Activision, Steve Cartwright) (AX-022) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\seaquest.bin
# copying sir_lancelot.bin from .\ROMS\ROMS\Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\sir_lancelot.bin
# copying skiing.bin from .\ROMS\ROMS\Skiing - Le Ski (1980) (Activision, Bob Whitehead) (AG-005, CAG-005, AG-005-04) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\skiing.bin
# copying solaris.bin from .\ROMS\ROMS\Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\solaris.bin
# copying space_invaders.bin from .\ROMS\ROMS\Space Invaders (1980) (Atari, Richard Maurer - Sears) (CX2632 - 49-75153) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\space_invaders.bin
# copying star_gunner.bin from .\ROMS\ROMS\Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\star_gunner.bin
# copying surround.bin from .\ROMS\ROMS\Surround (32 in 1) (Bit Corporation) (R320).bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\surround.bin
# copying tennis.bin from .\ROMS\ROMS\Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\tennis.bin
# copying time_pilot.bin from .\ROMS\ROMS\Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\time_pilot.bin
# copying trondead.bin from .\ROMS\ROMS\TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\trondead.bin
# copying tutankham.bin from .\ROMS\ROMS\Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\tutankham.bin
# copying up_n_down.bin from .\ROMS\ROMS\Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\up_n_down.bin
# copying venture.bin from .\ROMS\ROMS\Venture (1982) (Coleco, Joseph Biel) (2457) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\venture.bin
# copying pong.bin from .\ROMS\ROMS\Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\pong.bin
# copying wizard_of_wor.bin from .\ROMS\ROMS\Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\wizard_of_wor.bin
# copying yars_revenge.bin from .\ROMS\ROMS\Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\yars_revenge.bin
# copying zaxxon.bin from .\ROMS\ROMS\Zaxxon (1983) (Coleco) (2454) ~.bin to C:\Users\Admin\anaconda3\lib\site-packages\atari_py\atari_roms\zaxxon.bin

# %%
environment_name = "Breakout-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:0.0
# Episode:2 Score:2.0
# Episode:3 Score:2.0
# Episode:4 Score:1.0
# Episode:5 Score:0.0

# %%
env.action_space.sample()
# Out:
# 3

# %%
env.observation_space
# Out:
# Box(0, 255, (210, 160, 3), uint8)

# %% [markdown]
# # 3. Vectorise Environment and Train Model

# %%
env = make_atari_env('Breakout-v0', n_envs=4, seed=0)

# %%
env = VecFrameStack(env, n_stack=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = A2C("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training\Logs\A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 280      |
# |    ep_rew_mean        | 1.57     |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 100      |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.378   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0502  |
# |    value_loss         | 0.0133   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 299      |
# |    ep_rew_mean        | 1.9      |
# | time/                 |          |
# |    fps                | 30       |
# |    iterations         | 200      |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.67     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.37    |
# |    value_loss         | 0.089    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 304      |
# |    ep_rew_mean        | 1.97     |
# | time/                 |          |
# |    fps                | 30       |
# |    iterations         | 300      |
# |    time_elapsed       | 195      |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.878   |
# |    explained_variance | 0.713    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0251   |
# |    value_loss         | 0.083    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 316      |
# |    ep_rew_mean        | 2.18     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 400      |
# |    time_elapsed       | 255      |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0.938    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.147   |
# |    value_loss         | 0.0409   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 315      |
# |    ep_rew_mean        | 2.16     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 500      |
# |    time_elapsed       | 319      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.949   |
# |    explained_variance | 0.876    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.031   |
# |    value_loss         | 0.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 315      |
# |    ep_rew_mean        | 2.16     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 600      |
# |    time_elapsed       | 384      |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.888   |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.00382 |
# |    value_loss         | 0.00409  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 311      |
# |    ep_rew_mean        | 2.1      |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 700      |
# |    time_elapsed       | 450      |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | 0.813    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0447   |
# |    value_loss         | 0.0186   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 313      |
# |    ep_rew_mean        | 2.16     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 800      |
# |    time_elapsed       | 514      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.954   |
# |    explained_variance | 0.884    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0261   |
# |    value_loss         | 0.0162   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 312      |
# |    ep_rew_mean        | 2.14     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 900      |
# |    time_elapsed       | 576      |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.926   |
# |    explained_variance | 0.584    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.371    |
# |    value_loss         | 0.241    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 313      |
# |    ep_rew_mean        | 2.16     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 1000     |
# |    time_elapsed       | 640      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0516   |
# |    value_loss         | 0.0279   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 327      |
# |    ep_rew_mean        | 2.38     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 1100     |
# |    time_elapsed       | 701      |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.883    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.115   |
# |    value_loss         | 0.063    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 333      |
# |    ep_rew_mean        | 2.5      |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 1200     |
# |    time_elapsed       | 765      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.931    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.0512  |
# |    value_loss         | 0.0109   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 335      |
# |    ep_rew_mean        | 2.55     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 1300     |
# |    time_elapsed       | 829      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.87    |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0256  |
# |    value_loss         | 0.0349   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 342      |
# |    ep_rew_mean        | 2.75     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 1400     |
# |    time_elapsed       | 886      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.88    |
# |    explained_variance | 0.867    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0816  |
# |    value_loss         | 0.0586   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 349      |
# |    ep_rew_mean        | 2.99     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 1500     |
# |    time_elapsed       | 946      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.596    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.0839   |
# |    value_loss         | 0.0588   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 365      |
# |    ep_rew_mean        | 3.41     |
# | time/                 |          |
# |    fps                | 31       |
# |    iterations         | 1600     |
# |    time_elapsed       | 1004     |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.886   |
# |    explained_variance | 0.755    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.0368   |
# |    value_loss         | 0.119    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 386      |
# |    ep_rew_mean        | 3.91     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 1700     |
# |    time_elapsed       | 1062     |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.996   |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.0798  |
# |    value_loss         | 0.0186   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 405      |
# |    ep_rew_mean        | 4.29     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 1800     |
# |    time_elapsed       | 1123     |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.591   |
# |    explained_variance | 0.871    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.141    |
# |    value_loss         | 0.0523   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 406      |
# |    ep_rew_mean        | 4.3      |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 1900     |
# |    time_elapsed       | 1185     |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.347   |
# |    explained_variance | -1.04    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.113    |
# |    value_loss         | 1.27     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 428      |
# |    ep_rew_mean        | 4.72     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 2000     |
# |    time_elapsed       | 1248     |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.0955  |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00275  |
# |    value_loss         | 0.0682   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 432       |
# |    ep_rew_mean        | 4.79      |
# | time/                 |           |
# |    fps                | 32        |
# |    iterations         | 2100      |
# |    time_elapsed       | 1310      |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -0.0946   |
# |    explained_variance | 0.978     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.000419 |
# |    value_loss         | 0.0471    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 445      |
# |    ep_rew_mean        | 5.06     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 2200     |
# |    time_elapsed       | 1371     |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.388   |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0142   |
# |    value_loss         | 0.0426   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 447      |
# |    ep_rew_mean        | 5.16     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 2300     |
# |    time_elapsed       | 1426     |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.172   |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0309  |
# |    value_loss         | 0.124    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 454       |
# |    ep_rew_mean        | 5.4       |
# | time/                 |           |
# |    fps                | 32        |
# |    iterations         | 2400      |
# |    time_elapsed       | 1476      |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -0.192    |
# |    explained_variance | 0.959     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -0.000138 |
# |    value_loss         | 0.042     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 453      |
# |    ep_rew_mean        | 5.4      |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 2500     |
# |    time_elapsed       | 1527     |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.0601  |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.00167 |
# |    value_loss         | 0.0416   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 459      |
# |    ep_rew_mean        | 5.48     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 2600     |
# |    time_elapsed       | 1584     |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.262   |
# |    explained_variance | 0.891    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0578  |
# |    value_loss         | 0.113    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 5.34     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 2700     |
# |    time_elapsed       | 1642     |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.119   |
# |    explained_variance | 0.903    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00588  |
# |    value_loss         | 0.0718   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 445      |
# |    ep_rew_mean        | 5.14     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 2800     |
# |    time_elapsed       | 1701     |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.102   |
# |    explained_variance | 0.878    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00226  |
# |    value_loss         | 0.0333   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 446      |
# |    ep_rew_mean        | 5.16     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 2900     |
# |    time_elapsed       | 1768     |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.3     |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.00319  |
# |    value_loss         | 0.0302   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 434      |
# |    ep_rew_mean        | 4.88     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3000     |
# |    time_elapsed       | 1831     |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.136   |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00408  |
# |    value_loss         | 0.184    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 421      |
# |    ep_rew_mean        | 4.67     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3100     |
# |    time_elapsed       | 1895     |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | -2.85    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0148  |
# |    value_loss         | 0.455    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 417      |
# |    ep_rew_mean        | 4.58     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3200     |
# |    time_elapsed       | 1953     |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.44    |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0485   |
# |    value_loss         | 0.0714   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 415      |
# |    ep_rew_mean        | 4.51     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3300     |
# |    time_elapsed       | 2016     |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.354   |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.135   |
# |    value_loss         | 0.0283   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 418      |
# |    ep_rew_mean        | 4.66     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3400     |
# |    time_elapsed       | 2081     |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.157   |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.0146   |
# |    value_loss         | 0.0415   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 431      |
# |    ep_rew_mean        | 4.94     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3500     |
# |    time_elapsed       | 2143     |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | 0.947    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0167  |
# |    value_loss         | 0.00546  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 447      |
# |    ep_rew_mean        | 5.26     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3600     |
# |    time_elapsed       | 2206     |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.271   |
# |    explained_variance | 0.942    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.018   |
# |    value_loss         | 0.0232   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 461      |
# |    ep_rew_mean        | 5.6      |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3700     |
# |    time_elapsed       | 2260     |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -0.381   |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0018   |
# |    value_loss         | 0.0387   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 468      |
# |    ep_rew_mean        | 5.79     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3800     |
# |    time_elapsed       | 2313     |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.397   |
# |    explained_variance | 0.975    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0134   |
# |    value_loss         | 0.0311   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 485      |
# |    ep_rew_mean        | 6.04     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 3900     |
# |    time_elapsed       | 2366     |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -0.343   |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.00625 |
# |    value_loss         | 0.0319   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 487      |
# |    ep_rew_mean        | 6.13     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 4000     |
# |    time_elapsed       | 2419     |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.742   |
# |    explained_variance | 0.763    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0738   |
# |    value_loss         | 0.105    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 489      |
# |    ep_rew_mean        | 6.12     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 4100     |
# |    time_elapsed       | 2478     |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -0.252   |
# |    explained_variance | 0.776    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.215   |
# |    value_loss         | 0.198    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 477      |
# |    ep_rew_mean        | 5.75     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 4200     |
# |    time_elapsed       | 2535     |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.449   |
# |    explained_variance | 0.528    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.14     |
# |    value_loss         | 0.0782   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 476      |
# |    ep_rew_mean        | 5.61     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 4300     |
# |    time_elapsed       | 2613     |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.242   |
# |    explained_variance | 0.809    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0703  |
# |    value_loss         | 0.132    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 465      |
# |    ep_rew_mean        | 5.35     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 4400     |
# |    time_elapsed       | 2668     |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.624   |
# |    explained_variance | 0.586    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.163    |
# |    value_loss         | 0.0664   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 460      |
# |    ep_rew_mean        | 5.22     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 4500     |
# |    time_elapsed       | 2721     |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.249   |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0247   |
# |    value_loss         | 0.107    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 466      |
# |    ep_rew_mean        | 5.45     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 4600     |
# |    time_elapsed       | 2773     |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.71    |
# |    explained_variance | 0.93     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.0163  |
# |    value_loss         | 0.0771   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 483      |
# |    ep_rew_mean        | 5.84     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 4700     |
# |    time_elapsed       | 2827     |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.457   |
# |    explained_variance | 0.725    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.115    |
# |    value_loss         | 0.126    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | 6.34     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 4800     |
# |    time_elapsed       | 2882     |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | 0.912    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.145   |
# |    value_loss         | 0.0583   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 509      |
# |    ep_rew_mean        | 6.66     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 4900     |
# |    time_elapsed       | 2936     |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.255   |
# |    explained_variance | 0.872    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.00185 |
# |    value_loss         | 0.109    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 513      |
# |    ep_rew_mean        | 6.79     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5000     |
# |    time_elapsed       | 2991     |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | 0.844    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.111    |
# |    value_loss         | 0.0758   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 515      |
# |    ep_rew_mean        | 6.85     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5100     |
# |    time_elapsed       | 3045     |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -0.608   |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.0493  |
# |    value_loss         | 0.0166   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 503      |
# |    ep_rew_mean        | 6.53     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5200     |
# |    time_elapsed       | 3101     |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.656   |
# |    explained_variance | 0.918    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.194   |
# |    value_loss         | 0.0488   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 486      |
# |    ep_rew_mean        | 6.15     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5300     |
# |    time_elapsed       | 3148     |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -0.441   |
# |    explained_variance | 0.849    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0306  |
# |    value_loss         | 0.0974   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 482      |
# |    ep_rew_mean        | 6.01     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5400     |
# |    time_elapsed       | 3203     |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -0.483   |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.000115 |
# |    value_loss         | 0.106    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 488      |
# |    ep_rew_mean        | 6.07     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5500     |
# |    time_elapsed       | 3258     |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -0.397   |
# |    explained_variance | 0.819    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.00515  |
# |    value_loss         | 0.134    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 494      |
# |    ep_rew_mean        | 6.22     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5600     |
# |    time_elapsed       | 3314     |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.397   |
# |    explained_variance | 0.664    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.125   |
# |    value_loss         | 0.238    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 493      |
# |    ep_rew_mean        | 6.17     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5700     |
# |    time_elapsed       | 3371     |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -0.719   |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.155   |
# |    value_loss         | 0.0445   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 492      |
# |    ep_rew_mean        | 6.14     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5800     |
# |    time_elapsed       | 3430     |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -0.888   |
# |    explained_variance | 0.816    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.112    |
# |    value_loss         | 0.112    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 497      |
# |    ep_rew_mean        | 6.17     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 5900     |
# |    time_elapsed       | 3500     |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -0.716   |
# |    explained_variance | 0.593    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.226   |
# |    value_loss         | 0.162    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 490      |
# |    ep_rew_mean        | 6.06     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6000     |
# |    time_elapsed       | 3573     |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | 0.856    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.0767  |
# |    value_loss         | 0.0308   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 480      |
# |    ep_rew_mean        | 5.82     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6100     |
# |    time_elapsed       | 3648     |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -0.649   |
# |    explained_variance | 0.873    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0619  |
# |    value_loss         | 0.109    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 487      |
# |    ep_rew_mean        | 5.97     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6200     |
# |    time_elapsed       | 3724     |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.367   |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.00363  |
# |    value_loss         | 0.0175   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 498      |
# |    ep_rew_mean        | 6.17     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6300     |
# |    time_elapsed       | 3789     |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -0.353   |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0415  |
# |    value_loss         | 0.0924   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 499      |
# |    ep_rew_mean        | 6.24     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6400     |
# |    time_elapsed       | 3850     |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.263   |
# |    explained_variance | 0.799    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.016    |
# |    value_loss         | 0.102    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 499      |
# |    ep_rew_mean        | 6.26     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6500     |
# |    time_elapsed       | 3906     |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -0.311   |
# |    explained_variance | 0.9      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.13    |
# |    value_loss         | 0.0878   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 523      |
# |    ep_rew_mean        | 6.68     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6600     |
# |    time_elapsed       | 3959     |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.119   |
# |    explained_variance | 0.686    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.0246   |
# |    value_loss         | 0.0892   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 526      |
# |    ep_rew_mean        | 6.71     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6700     |
# |    time_elapsed       | 4023     |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -0.259   |
# |    explained_variance | -2.52    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0148  |
# |    value_loss         | 0.156    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 527      |
# |    ep_rew_mean        | 6.7      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6800     |
# |    time_elapsed       | 4082     |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.39    |
# |    explained_variance | 0.842    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.123    |
# |    value_loss         | 0.246    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 530      |
# |    ep_rew_mean        | 6.74     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 6900     |
# |    time_elapsed       | 4143     |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -0.264   |
# |    explained_variance | 0.941    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.0514   |
# |    value_loss         | 0.0387   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 541      |
# |    ep_rew_mean        | 6.99     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 7000     |
# |    time_elapsed       | 4204     |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.209   |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.00449 |
# |    value_loss         | 0.142    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 550       |
# |    ep_rew_mean        | 7.06      |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 7100      |
# |    time_elapsed       | 4286      |
# |    total_timesteps    | 142000    |
# | train/                |           |
# |    entropy_loss       | -0.209    |
# |    explained_variance | 0.902     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000774 |
# |    value_loss         | 0.0989    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 554      |
# |    ep_rew_mean        | 7.24     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 7200     |
# |    time_elapsed       | 4413     |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.0234  |
# |    explained_variance | 0.904    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.00221 |
# |    value_loss         | 0.0253   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 548      |
# |    ep_rew_mean        | 7.1      |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 7300     |
# |    time_elapsed       | 4512     |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -0.441   |
# |    explained_variance | 0.882    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.0343  |
# |    value_loss         | 0.0652   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 553      |
# |    ep_rew_mean        | 7.24     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 7400     |
# |    time_elapsed       | 4572     |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.547   |
# |    explained_variance | 0.0222   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.045   |
# |    value_loss         | 0.146    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 554      |
# |    ep_rew_mean        | 7.32     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 7500     |
# |    time_elapsed       | 4629     |
# |    total_timesteps    | 150000   |
# | train/                |          |
# |    entropy_loss       | -0.288   |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.0381  |
# |    value_loss         | 0.0382   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 541      |
# |    ep_rew_mean        | 7.07     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 7600     |
# |    time_elapsed       | 4686     |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.174   |
# |    explained_variance | 0.918    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.0421   |
# |    value_loss         | 0.0923   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# ...
# |    explained_variance | 0.381    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17499    |
# |    policy_loss        | 0.00697  |
# |    value_loss         | 0.171    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 628      |
# |    ep_rew_mean        | 9.09     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 17600    |
# |    time_elapsed       | 10685    |
# |    total_timesteps    | 352000   |
# | train/                |          |
# |    entropy_loss       | -0.188   |
# |    explained_variance | 0.835    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17599    |
# |    policy_loss        | 0.117    |
# |    value_loss         | 0.26     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 652      |
# |    ep_rew_mean        | 9.68     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 17700    |
# |    time_elapsed       | 10741    |
# |    total_timesteps    | 354000   |
# | train/                |          |
# |    entropy_loss       | -0.187   |
# |    explained_variance | 0.578    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | -0.0274  |
# |    value_loss         | 0.396    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 667      |
# |    ep_rew_mean        | 10.1     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 17800    |
# |    time_elapsed       | 10801    |
# |    total_timesteps    | 356000   |
# | train/                |          |
# |    entropy_loss       | -0.284   |
# |    explained_variance | 0.894    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | 0.157    |
# |    value_loss         | 0.0606   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 670      |
# |    ep_rew_mean        | 10.2     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 17900    |
# |    time_elapsed       | 10860    |
# |    total_timesteps    | 358000   |
# | train/                |          |
# |    entropy_loss       | -0.249   |
# |    explained_variance | -0.101   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | -0.103   |
# |    value_loss         | 0.161    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 683      |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 18000    |
# |    time_elapsed       | 10913    |
# |    total_timesteps    | 360000   |
# | train/                |          |
# |    entropy_loss       | -0.153   |
# |    explained_variance | 0.859    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | -0.132   |
# |    value_loss         | 0.252    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 678      |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 18100    |
# |    time_elapsed       | 10965    |
# |    total_timesteps    | 362000   |
# | train/                |          |
# |    entropy_loss       | -0.248   |
# |    explained_variance | -0.0277  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 0.0125   |
# |    value_loss         | 0.336    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 686      |
# |    ep_rew_mean        | 10.7     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 18200    |
# |    time_elapsed       | 11021    |
# |    total_timesteps    | 364000   |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | 0.909    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | -0.253   |
# |    value_loss         | 0.126    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 688      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 18300    |
# |    time_elapsed       | 11087    |
# |    total_timesteps    | 366000   |
# | train/                |          |
# |    entropy_loss       | -0.43    |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | 0.043    |
# |    value_loss         | 0.018    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 681      |
# |    ep_rew_mean        | 10.7     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 18400    |
# |    time_elapsed       | 11153    |
# |    total_timesteps    | 368000   |
# | train/                |          |
# |    entropy_loss       | -0.14    |
# |    explained_variance | 0.668    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | -0.0239  |
# |    value_loss         | 0.134    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 673      |
# |    ep_rew_mean        | 10.5     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 18500    |
# |    time_elapsed       | 11208    |
# |    total_timesteps    | 370000   |
# | train/                |          |
# |    entropy_loss       | -0.28    |
# |    explained_variance | -0.728   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 0.13     |
# |    value_loss         | 0.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 672      |
# |    ep_rew_mean        | 10.5     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 18600    |
# |    time_elapsed       | 11267    |
# |    total_timesteps    | 372000   |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | 0.908    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 0.0212   |
# |    value_loss         | 0.0451   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 673      |
# |    ep_rew_mean        | 10.4     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 18700    |
# |    time_elapsed       | 11327    |
# |    total_timesteps    | 374000   |
# | train/                |          |
# |    entropy_loss       | -0.34    |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | 0.033    |
# |    value_loss         | 0.0265   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 655      |
# |    ep_rew_mean        | 9.86     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 18800    |
# |    time_elapsed       | 11391    |
# |    total_timesteps    | 376000   |
# | train/                |          |
# |    entropy_loss       | -0.582   |
# |    explained_variance | 0.526    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | 0.0606   |
# |    value_loss         | 0.183    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 655      |
# |    ep_rew_mean        | 9.81     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 18900    |
# |    time_elapsed       | 11456    |
# |    total_timesteps    | 378000   |
# | train/                |          |
# |    entropy_loss       | -0.328   |
# |    explained_variance | -0.156   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | 0.112    |
# |    value_loss         | 0.199    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 658      |
# |    ep_rew_mean        | 9.86     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 19000    |
# |    time_elapsed       | 11519    |
# |    total_timesteps    | 380000   |
# | train/                |          |
# |    entropy_loss       | -0.294   |
# |    explained_variance | 0.9      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | -0.00641 |
# |    value_loss         | 0.094    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 657      |
# |    ep_rew_mean        | 9.93     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 19100    |
# |    time_elapsed       | 11578    |
# |    total_timesteps    | 382000   |
# | train/                |          |
# |    entropy_loss       | -0.56    |
# |    explained_variance | 0.953    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 0.0749   |
# |    value_loss         | 0.0456   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 672      |
# |    ep_rew_mean        | 10.1     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 19200    |
# |    time_elapsed       | 11644    |
# |    total_timesteps    | 384000   |
# | train/                |          |
# |    entropy_loss       | -0.185   |
# |    explained_variance | 0.753    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | 0.0131   |
# |    value_loss         | 0.143    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 689      |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 19300    |
# |    time_elapsed       | 11702    |
# |    total_timesteps    | 386000   |
# | train/                |          |
# |    entropy_loss       | -0.27    |
# |    explained_variance | 0.939    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | -0.00995 |
# |    value_loss         | 0.0571   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 681      |
# |    ep_rew_mean        | 10.5     |
# | time/                 |          |
# |    fps                | 32       |
# |    iterations         | 19400    |
# |    time_elapsed       | 11758    |
# |    total_timesteps    | 388000   |
# | train/                |          |
# |    entropy_loss       | -0.398   |
# |    explained_variance | 0.927    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | -0.0385  |
# |    value_loss         | 0.151    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 691      |
# |    ep_rew_mean        | 10.7     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 19500    |
# |    time_elapsed       | 11809    |
# |    total_timesteps    | 390000   |
# | train/                |          |
# |    entropy_loss       | -0.369   |
# |    explained_variance | 0.59     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | -0.0791  |
# |    value_loss         | 0.0667   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 706      |
# |    ep_rew_mean        | 11       |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 19600    |
# |    time_elapsed       | 11861    |
# |    total_timesteps    | 392000   |
# | train/                |          |
# |    entropy_loss       | -0.243   |
# |    explained_variance | 0.677    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | -0.143   |
# |    value_loss         | 0.513    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 700       |
# |    ep_rew_mean        | 10.9      |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 19700     |
# |    time_elapsed       | 11913     |
# |    total_timesteps    | 394000    |
# | train/                |           |
# |    entropy_loss       | -0.000152 |
# |    explained_variance | 0.117     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -1.75e-05 |
# |    value_loss         | 0.274     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 670      |
# |    ep_rew_mean        | 10       |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 19800    |
# |    time_elapsed       | 11966    |
# |    total_timesteps    | 396000   |
# | train/                |          |
# |    entropy_loss       | -0.33    |
# |    explained_variance | 0.947    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19799    |
# |    policy_loss        | 0.00763  |
# |    value_loss         | 0.0667   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 668      |
# |    ep_rew_mean        | 10.1     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 19900    |
# |    time_elapsed       | 12019    |
# |    total_timesteps    | 398000   |
# | train/                |          |
# |    entropy_loss       | -0.219   |
# |    explained_variance | 0.934    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | 0.0594   |
# |    value_loss         | 0.0463   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 672      |
# |    ep_rew_mean        | 10.1     |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 20000    |
# |    time_elapsed       | 12093    |
# |    total_timesteps    | 400000   |
# | train/                |          |
# |    entropy_loss       | -0.166   |
# |    explained_variance | 0.801    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | -0.0761  |
# |    value_loss         | 0.19     |
# ------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'A2C_model')

# %%
model.save(a2c_path)

# %%
del model

# %%
env = make_atari_env('Breakout-v0', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (13.2, 3.7629775444453557)

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
env.close()
